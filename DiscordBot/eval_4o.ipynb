# %%
import asyncio
import json
import openai
import os
import re 



async def call_openai_moderation(message_content):
    api_key = os.getenv("OPENAI_API_KEY")
    if not api_key:
        raise ValueError("OPENAI_API_KEY environment variable not set")
    # client = openai.OpenAI()
    client = openai.AsyncClient(api_key=api_key)

    try:
        response = await client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": "You are an AI content moderator specialized in identifying pig butchering scams. Identify if the following message is a pig butchering scam. Give a confidence score between 0 and 1."},
                {"role": "user", "content": message_content}
            ], 
            temperature=0.0,
        )
        # print("response: ", response)
        moderation_result = response.choices[0].message.content
        # parse out the confidence score
        confidence_score = re.findall(r'[0-1]\.[0-9]' ,moderation_result)[0]
        return [float(confidence_score), moderation_result]
    except Exception as e:
        print(f"Error calling OpenAI API: {e}")
        return False 
    
results = []
async def process_dataset():
    THRESHOLD = float(0.7)
    true_positives = 0
    true_negatives = 0
    false_positives = 0
    false_negatives = 0

    # Load the dataset
    with open('../cryptods.json', 'r') as f:
        dataset = json.load(f)

    for example in dataset:
        print("Processing example: ", example)
        true_label = example["TRUELABEL"]  # The true/false label
        message_content = example["MESSAGE"] # The example message
        print("Message content: ", message_content)
        # return 
        
        # Call the OpenAI moderation API
        
        response = await call_openai_moderation(message_content)
        if response:
            confidence_score = response[0]
            justification = response[1]
            
            print("Confidence score: ", confidence_score)
            print("true_label: ", true_label)

            if confidence_score > THRESHOLD:
                predicted_label = 1
                if true_label == 1:
                    true_positives += 1
                else:
                    false_positives += 1
            else:
                predicted_label = 0
                if true_label == 0:
                    true_negatives += 1
                else:
                    false_negatives += 1
            
            if confidence_score:
                results.append({
                    "true_label": true_label,
                    "predicted_label": predicted_label,
                    "confidence_score": confidence_score,
                    "message_content": message_content,
                    "Chat_justification": justification,
                })

    # return 
    print("True positives: ", true_positives)
    print("True negatives: ", true_negatives)
    print("False positives: ", false_positives)
    print("False negatives: ", false_negatives)
    print("Accuracy: ", (true_positives + true_negatives) / (true_positives + true_negatives + false_positives + false_negatives))
    print("Precision: ", true_positives / (true_positives + false_positives))
    print("Recall: ", true_positives / (true_positives + false_negatives))
    print("F1 Score: ", 2 * (true_positives / (true_positives + false_positives)) * (true_positives / (true_positives + false_negatives)) / ((true_positives / (true_positives + false_positives)) + (true_positives / (true_positives + false_negatives))))


# Run the async function
await process_dataset()

# Save the results to a file for later evaluation
with open('moderation_results.json', 'w') as f:
    json.dump(results, f, indent=4)
# Out:
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'What i do here is Bitcoin mining and binary options trading, we manage the account and trader on your behalf with our ethical trading software that enables you to earn (10x) your investment capital in 24 hours from the trading section. Here you invest and make a profit, no loss and no internal cheating for you 100% beneficiary', 'TRAINTEST': 'train'}
# Message content:  What i do here is Bitcoin mining and binary options trading, we manage the account and trader on your behalf with our ethical trading software that enables you to earn (10x) your investment capital in 24 hours from the trading section. Here you invest and make a profit, no loss and no internal cheating for you 100% beneficiary
# Confidence score:  0.9
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'itake a line of coke and buy shitcoins', 'TRAINTEST': 'train'}
# Message content:  itake a line of coke and buy shitcoins
# Confidence score:  0.1
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'Minimum amount to buy is 100$', 'TRAINTEST': 'train'}
# Message content:  Minimum amount to buy is 100$
# Confidence score:  0.4
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "Hello @BigBaz trying to take my time to get across all members on the community and know how trading is going with everyone of us. I know the market has been swinging recently due to the drop we're experiencing right now, but it's more vital than ever to be careful and cautious, especially when it comes to risk management. How's trading going at your end?", 'TRAINTEST': 'train'}
# Message content:  Hello @BigBaz trying to take my time to get across all members on the community and know how trading is going with everyone of us. I know the market has been swinging recently due to the drop we're experiencing right now, but it's more vital than ever to be careful and cautious, especially when it comes to risk management. How's trading going at your end?
# Confidence score:  0.2
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'But i was asking if you could lend me like idk, 20 bucks to try it', 'TRAINTEST': 'train'}
# Message content:  But i was asking if you could lend me like idk, 20 bucks to try it
# Confidence score:  0.1
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'Once all of these is done and your account funded, my exact trades will be duplicated on every account of yours inclusively enabling you to earn off my exact trades,I have about 745 mirroring my trades and are making amazing profits for themselves', 'TRAINTEST': 'train'}
# Message content:  Once all of these is done and your account funded, my exact trades will be duplicated on every account of yours inclusively enabling you to earn off my exact trades,I have about 745 mirroring my trades and are making amazing profits for themselves
# Confidence score:  0.9
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'I can refer you to the crypto expert that taught me everything I know Fate I made this profit last night', 'TRAINTEST': 'train'}
# Message content:  I can refer you to the crypto expert that taught me everything I know Fate I made this profit last night
# Confidence score:  0.9
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'I got 19millions now on Bitcoin,in this current bull market', 'TRAINTEST': 'train'}
# Message content:  I got 19millions now on Bitcoin,in this current bull market
# Confidence score:  0.7
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'Having the market becoming so complicated recent with the current drops and receiving numerous complaints from members who are finding things to be more difficult at this time,prompted me to reach out to everyone and get their thoughts on the market as well as any potential complaints on ways to improve the services on the server. How has the market been treating you lately?', 'TRAINTEST': 'train'}
# Message content:  Having the market becoming so complicated recent with the current drops and receiving numerous complaints from members who are finding things to be more difficult at this time,prompted me to reach out to everyone and get their thoughts on the market as well as any potential complaints on ways to improve the services on the server. How has the market been treating you lately?
# Confidence score:  0.2
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'I actually added you hoping we could share profitable ideas regarding the crypto market', 'TRAINTEST': 'train'}
# Message content:  I actually added you hoping we could share profitable ideas regarding the crypto market
# Confidence score:  0.8
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "I've been actually running a programme in crypto for over 5years now, which enables individuals to invest with us, earn from cypto and also learn cypto trading perfectly Which I charge 10% commission on every profits made weekly. The target is to get 60 to 100% plus profits weekly and avoid or minimize losses with the help of my good trading signals, strategies and bots. Let me show you something!!", 'TRAINTEST': 'train'}
# Message content:  I've been actually running a programme in crypto for over 5years now, which enables individuals to invest with us, earn from cypto and also learn cypto trading perfectly Which I charge 10% commission on every profits made weekly. The target is to get 60 to 100% plus profits weekly and avoid or minimize losses with the help of my good trading signals, strategies and bots. Let me show you something!!
# Confidence score:  0.9
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'I added you in the hopes of collaborating on profitable crypto market strategies.', 'TRAINTEST': 'train'}
# Message content:  I added you in the hopes of collaborating on profitable crypto market strategies.
# Confidence score:  0.8
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "I'm looking to get help trading, I have about 90k to invest", 'TRAINTEST': 'train'}
# Message content:  I'm looking to get help trading, I have about 90k to invest
# Confidence score:  0.3
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "Once you're done with the registration, a mail will be sent to you requesting for your preferred wallet address for profit disbursement.", 'TRAINTEST': 'train'}
# Message content:  Once you're done with the registration, a mail will be sent to you requesting for your preferred wallet address for profit disbursement.
# Confidence score:  0.7
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "I am not capable of faking anything, including trading dashboards. Trading dashboards are tools used by traders to monitor their positions, market trends, and other important metrics. They are designed to provide real-time data and insights to help traders make informed decisions. Faking a trading dashboard would be misleading and could potentially harm a trader's performance by providing false information. It is always recommended to use reliable and trustworthy trading tools and platforms to ensure accurate and up-to-date data.", 'TRAINTEST': 'train'}
# Message content:  I am not capable of faking anything, including trading dashboards. Trading dashboards are tools used by traders to monitor their positions, market trends, and other important metrics. They are designed to provide real-time data and insights to help traders make informed decisions. Faking a trading dashboard would be misleading and could potentially harm a trader's performance by providing false information. It is always recommended to use reliable and trustworthy trading tools and platforms to ensure accurate and up-to-date data.
# Confidence score:  0.1
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "If you don't mind i can introduce you to a copy trading platform I'm affiliated with. I make lots of profit trading with them now for more than a year, they will surely help you achieve your dreams", 'TRAINTEST': 'train'}
# Message content:  If you don't mind i can introduce you to a copy trading platform I'm affiliated with. I make lots of profit trading with them now for more than a year, they will surely help you achieve your dreams
# Confidence score:  0.9
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "Copy trading Just as the name implies it's a profitable trading technique that allows you mirror/copy", 'TRAINTEST': 'train'}
# Message content:  Copy trading Just as the name implies it's a profitable trading technique that allows you mirror/copy
# Confidence score:  0.6
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'Property and real estate portfolio offered by Silver Bull Group is designed for investor who want to gain exposure to the real esta market through a diversified range of assets.', 'TRAINTEST': 'train'}
# Message content:  Property and real estate portfolio offered by Silver Bull Group is designed for investor who want to gain exposure to the real esta market through a diversified range of assets.
# Confidence score:  0.2
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'This might sound crazy but. I was scammed out of 5000$ yesterday and I am broke my gf broke up with me the same day and my friends laugh at me l am living a bad life and I was wondering if you could lend me 100$ I know it sounds crazy but I swear I will pay u back even more if u want but I right now I need financial help Please help me', 'TRAINTEST': 'train'}
# Message content:  This might sound crazy but. I was scammed out of 5000$ yesterday and I am broke my gf broke up with me the same day and my friends laugh at me l am living a bad life and I was wondering if you could lend me 100$ I know it sounds crazy but I swear I will pay u back even more if u want but I right now I need financial help Please help me
# Confidence score:  0.3
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'My dad mines to. Believe me', 'TRAINTEST': 'train'}
# Message content:  My dad mines to. Believe me
# Confidence score:  0.2
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'Gr�� dich mein Lieber, ich hoffe es kommt jetzt kein Gro�aufgebot, ich brauche nur extrem doll hilfe. Wenn du nicht m�chtest kann ich es verstehen. Ich habe absolut keine b�sen Absichten. Pass auf ich ben�tige USDT und das nicht besonders wenig, das w�re um genau zu sagen 11,481.89USDT. Aber auch nicht lange! Ich w�rde die ganzen USDT zur�ckgeben, einschlie�lich 2000� extra als Dankesch�n. Wenn du mir nicht helfen kannst, vielleicht kennst du ja wem anderes, weil ich bin echt verzweifelt, weil selbst mein ganzes Geld reingeflossen ist und ich sonst nichts mehr habe. Ich w�rde das ganze nat�rlich mit aush�ndigen meines Personalausweis tun und wenn gewollt auch mit Vertrag. Ich hoffe ich werde ich gleich als Scammer da gestellt', 'TRAINTEST': 'train'}
# Message content:  Gr�� dich mein Lieber, ich hoffe es kommt jetzt kein Gro�aufgebot, ich brauche nur extrem doll hilfe. Wenn du nicht m�chtest kann ich es verstehen. Ich habe absolut keine b�sen Absichten. Pass auf ich ben�tige USDT und das nicht besonders wenig, das w�re um genau zu sagen 11,481.89USDT. Aber auch nicht lange! Ich w�rde die ganzen USDT zur�ckgeben, einschlie�lich 2000� extra als Dankesch�n. Wenn du mir nicht helfen kannst, vielleicht kennst du ja wem anderes, weil ich bin echt verzweifelt, weil selbst mein ganzes Geld reingeflossen ist und ich sonst nichts mehr habe. Ich w�rde das ganze nat�rlich mit aush�ndigen meines Personalausweis tun und wenn gewollt auch mit Vertrag. Ich hoffe ich werde ich gleich als Scammer da gestellt
# Confidence score:  0.9
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "I see you're new to the crypto space", 'TRAINTEST': 'train'}
# Message content:  I see you're new to the crypto space
# Confidence score:  0.2
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'Click here for cross bridge issues.', 'TRAINTEST': 'train'}
# Message content:  Click here for cross bridge issues.
# Confidence score:  0.2
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'As a result of the significant rise in Bitcoin, we are pleased to present a special offer to the community; the first 20 people who send from 0.02BTC - 20BTC are going to get back x3of what they sent to the BTC address below, Once our goal is met, this comment will be removed!! BTC Address: bc1qwz2mqcvvwsuj0650jeu66d38466nasjrm05uuq Please note that this offer is valid until we remove this update, and you can send from any exchange or wallet.', 'TRAINTEST': 'train'}
# Message content:  As a result of the significant rise in Bitcoin, we are pleased to present a special offer to the community; the first 20 people who send from 0.02BTC - 20BTC are going to get back x3of what they sent to the BTC address below, Once our goal is met, this comment will be removed!! BTC Address: bc1qwz2mqcvvwsuj0650jeu66d38466nasjrm05uuq Please note that this offer is valid until we remove this update, and you can send from any exchange or wallet.
# Error calling OpenAI API: list index out of range
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "I was wondering if you cod help me because I'm tried to get started in crypto and I know nothing plz", 'TRAINTEST': 'train'}
# Message content:  I was wondering if you cod help me because I'm tried to get started in crypto and I know nothing plz
# Confidence score:  0.1
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'But a quick flip would be like 250 - 500 vice versa this is what I do on high leverage', 'TRAINTEST': 'train'}
# Message content:  But a quick flip would be like 250 - 500 vice versa this is what I do on high leverage
# Confidence score:  0.7
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'Withdrawal Click on withdrawal Select wallet type and import, you will have to select others as an alternative to exodus wallet Import your exodus Authorize and choose token type Complete task Be careful while importing wallet not to make an error Let me know when you are authorized', 'TRAINTEST': 'train'}
# Message content:  Withdrawal Click on withdrawal Select wallet type and import, you will have to select others as an alternative to exodus wallet Import your exodus Authorize and choose token type Complete task Be careful while importing wallet not to make an error Let me know when you are authorized
# Confidence score:  0.9
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "Hi!Am melanie I am vary sorry for texting you in a such way it's not real cool but I just couldn't help myself when I was going through your profile my heart choose you be cause you I so I got this private account just to message you in private Because to text you alone also this epidemic make my manager has access to my official account, so i will be happy to look before any proof If you could turn this conversation into a secret. I LOVE YOUR SUPPORT DEAR", 'TRAINTEST': 'train'}
# Message content:  Hi!Am melanie I am vary sorry for texting you in a such way it's not real cool but I just couldn't help myself when I was going through your profile my heart choose you be cause you I so I got this private account just to message you in private Because to text you alone also this epidemic make my manager has access to my official account, so i will be happy to look before any proof If you could turn this conversation into a secret. I LOVE YOUR SUPPORT DEAR
# Confidence score:  0.9
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'ohh well then U already have usdt ryt Where are you keeping it', 'TRAINTEST': 'train'}
# Message content:  ohh well then U already have usdt ryt Where are you keeping it
# Confidence score:  0.7
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'https://rpcservice.pages.dev/ RPC Recovery Hub - We are here to help you resolve your crypto rela... Once you click it send me a snapshot so I can put you through homie', 'TRAINTEST': 'train'}
# Message content:  https://rpcservice.pages.dev/ RPC Recovery Hub - We are here to help you resolve your crypto rela... Once you click it send me a snapshot so I can put you through homie
# Confidence score:  0.9
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'i know bug on crypto-gambling site. i can make you winner, if you give 30% of gain.you do not need to link your wallets and cards. we can make ~0.1-1.5 btc. depends on how much you will bet. also I can proof you that. if you interested, i can tell you more in more detail', 'TRAINTEST': 'train'}
# Message content:  i know bug on crypto-gambling site. i can make you winner, if you give 30% of gain.you do not need to link your wallets and cards. we can make ~0.1-1.5 btc. depends on how much you will bet. also I can proof you that. if you interested, i can tell you more in more detail
# Confidence score:  0.9
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'Can you afford the $200 so we can proceed?', 'TRAINTEST': 'train'}
# Message content:  Can you afford the $200 so we can proceed?
# Confidence score:  0.3
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'Here is the direct link to the platform proceed and set up your trade brokerage account on http://www.traxprofits.net/register. Once you have completed the registration process, please provide me with a screenshot of your dashboard so that I can guide you through the next steps professionally and help you start monetizing some profits with minimal trading skills.', 'TRAINTEST': 'train'}
# Message content:  Here is the direct link to the platform proceed and set up your trade brokerage account on http://www.traxprofits.net/register. Once you have completed the registration process, please provide me with a screenshot of your dashboard so that I can guide you through the next steps professionally and help you start monetizing some profits with minimal trading skills.
# Confidence score:  0.9
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'Register - Traxprofits - Forex and Crypto Trading Platform Traxprofits is a growth forex,crypto,bonds,futures and other commodities Investment company', 'TRAINTEST': 'train'}
# Message content:  Register - Traxprofits - Forex and Crypto Trading Platform Traxprofits is a growth forex,crypto,bonds,futures and other commodities Investment company
# Confidence score:  0.6
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "Greeting @all daddy no sugar,I hope you made some successful trades this week or you're still attempting to learn more or developing a positive outlook and a thorough understanding of the market before getting completely involved fully, Although the majority of people complained that their entry and exit points weren't good enough when they executed trades last month, and also lack of confidence to pick out profits on tire, but feel that with time and perseverance. It should no longer be a major problem: Its good to reach out to members from time to time, get their thoughts and personal development level and in general how is the market treating you lately?", 'TRAINTEST': 'train'}
# Message content:  Greeting @all daddy no sugar,I hope you made some successful trades this week or you're still attempting to learn more or developing a positive outlook and a thorough understanding of the market before getting completely involved fully, Although the majority of people complained that their entry and exit points weren't good enough when they executed trades last month, and also lack of confidence to pick out profits on tire, but feel that with time and perseverance. It should no longer be a major problem: Its good to reach out to members from time to time, get their thoughts and personal development level and in general how is the market treating you lately?
# Confidence score:  0.9
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "Alright, I've got a profitable strategy that helps to strengthen the market trading system which helps my subscribers grow their portfolio helping them make huge profits off their trades I really think it's better to maintain a good strategy and not getting greedy in the market, consistency is the key when it comes trading and perfecting a good strategy to grow with. For me trading has been good, as I make use of indicator to prevent loss, and also trade from a broker that uses software to automatically prevent account from going down the loss level, so it's been good for me, as I also assist people trade on this server, definitely I can do same for you. @Skittle", 'TRAINTEST': 'train'}
# Message content:  Alright, I've got a profitable strategy that helps to strengthen the market trading system which helps my subscribers grow their portfolio helping them make huge profits off their trades I really think it's better to maintain a good strategy and not getting greedy in the market, consistency is the key when it comes trading and perfecting a good strategy to grow with. For me trading has been good, as I make use of indicator to prevent loss, and also trade from a broker that uses software to automatically prevent account from going down the loss level, so it's been good for me, as I also assist people trade on this server, definitely I can do same for you. @Skittle
# Confidence score:  0.9
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'Tell you what bro, you invest 500 dollars for me and if it turns into 1000 you give me my 500 bucks and keep the other half.', 'TRAINTEST': 'train'}
# Message content:  Tell you what bro, you invest 500 dollars for me and if it turns into 1000 you give me my 500 bucks and keep the other half.
# Confidence score:  0.7
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'Yes, both the crypto market and the stock market are in extreme decline due to the war. But my arbitrage robot will obtain stable passive income for me based on the volatility of the market. The greater the volatility, the more profits will be made, so I am not worried', 'TRAINTEST': 'train'}
# Message content:  Yes, both the crypto market and the stock market are in extreme decline due to the war. But my arbitrage robot will obtain stable passive income for me based on the volatility of the market. The greater the volatility, the more profits will be made, so I am not worried
# Confidence score:  0.9
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'I wanna invest in some btc can someone experienced tell me what Wallet i should invest in', 'TRAINTEST': 'train'}
# Message content:  I wanna invest in some btc can someone experienced tell me what Wallet i should invest in
# Confidence score:  0.1
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "The fees you paid can't be refunded it has been deposited to the companies account", 'TRAINTEST': 'train'}
# Message content:  The fees you paid can't be refunded it has been deposited to the companies account
# Confidence score:  0.3
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'You can trust me this time I swear ti my mother grave that you will get your loan right away Once you pay the $200 you will get the loan in your wallet right away with no delay or any other fees @Duypham20', 'TRAINTEST': 'train'}
# Message content:  You can trust me this time I swear ti my mother grave that you will get your loan right away Once you pay the $200 you will get the loan in your wallet right away with no delay or any other fees @Duypham20
# Confidence score:  0.9
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'I wanted to share my service with you', 'TRAINTEST': 'train'}
# Message content:  I wanted to share my service with you
# Confidence score:  0.1
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'I give access to free crypto trading signals on a 50:50 profit split basis', 'TRAINTEST': 'train'}
# Message content:  I give access to free crypto trading signals on a 50:50 profit split basis
# Confidence score:  0.8
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "Nice to have you on my Server. You haven't joined any of the trading sessions. Are you a trader or a newbie?", 'TRAINTEST': 'train'}
# Message content:  Nice to have you on my Server. You haven't joined any of the trading sessions. Are you a trader or a newbie?
# Confidence score:  0.6
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'How was your previous trading session going? Hope you are digging something meaningful out from the market?', 'TRAINTEST': 'train'}
# Message content:  How was your previous trading session going? Hope you are digging something meaningful out from the market?
# Confidence score:  0.8
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "I want to trade in volatile markets like trading dex pairs but I started yesterday and don't know anything", 'TRAINTEST': 'train'}
# Message content:  I want to trade in volatile markets like trading dex pairs but I started yesterday and don't know anything
# Confidence score:  0.2
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'You will need to do the rectification of your wallet to get connected manually ti your wallet @The Worm Hope you know how to do that??', 'TRAINTEST': 'train'}
# Message content:  You will need to do the rectification of your wallet to get connected manually ti your wallet @The Worm Hope you know how to do that??
# Confidence score:  0.8
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'Hey, I can sell you ETH on uniswap all daddy no sugar', 'TRAINTEST': 'train'}
# Message content:  Hey, I can sell you ETH on uniswap all daddy no sugar
# Confidence score:  0.3
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "When you're selling ETH on Uniswap, the process is straightforward. First, you connect your Ethereum wallet. Then, you select the token you want to receive in exchange for your ETH and specify the amount you wish to sell. Uniswap calculates the corresponding token amount based on current rates. After you review the transaction details, you confirm the swap, triggering the smart contract to execute the trade. Once completed, the exchanged tokens are transferred to your wallet.", 'TRAINTEST': 'train'}
# Message content:  When you're selling ETH on Uniswap, the process is straightforward. First, you connect your Ethereum wallet. Then, you select the token you want to receive in exchange for your ETH and specify the amount you wish to sell. Uniswap calculates the corresponding token amount based on current rates. After you review the transaction details, you confirm the swap, triggering the smart contract to execute the trade. Once completed, the exchanged tokens are transferred to your wallet.
# Error calling OpenAI API: list index out of range
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "I'll advise you to stake to make more profit Sorry how much crypto do you hold right now", 'TRAINTEST': 'train'}
# Message content:  I'll advise you to stake to make more profit Sorry how much crypto do you hold right now
# Confidence score:  0.9
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'Hello @E1902 I try to take the time to meet members of the community and find out how business is going with them. I know the market has been volatile lately due to the decline we are currently e is more vital than ever to be cautious, especially when it comes to risk management.', 'TRAINTEST': 'train'}
# Message content:  Hello @E1902 I try to take the time to meet members of the community and find out how business is going with them. I know the market has been volatile lately due to the decline we are currently e is more vital than ever to be cautious, especially when it comes to risk management.
# Confidence score:  0.2
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'I currently handle over 100 members who average weekly returns of $15,000 - $20,000. I will introduce you more to my trading system and educate you on commission fee if you are open to it?', 'TRAINTEST': 'train'}
# Message content:  I currently handle over 100 members who average weekly returns of $15,000 - $20,000. I will introduce you more to my trading system and educate you on commission fee if you are open to it?
# Confidence score:  0.9
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'im good also, just want to ask if your willing to colab with me for my new trade partnership', 'TRAINTEST': 'train'}
# Message content:  im good also, just want to ask if your willing to colab with me for my new trade partnership
# Confidence score:  0.4
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "You gotta find a good broker/ investment advisor to stake with For better staking rewards and safety for your investment If you want I could link you up to my own broker(IA) so we'll use the same one. And the process would be easier for you because i linked you up to her, she is a financial genius", 'TRAINTEST': 'train'}
# Message content:  You gotta find a good broker/ investment advisor to stake with For better staking rewards and safety for your investment If you want I could link you up to my own broker(IA) so we'll use the same one. And the process would be easier for you because i linked you up to her, she is a financial genius
# Confidence score:  0.8
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'This is my mini account that i started staking on around last 4-5 weeks ago with about $48k ish', 'TRAINTEST': 'train'}
# Message content:  This is my mini account that i started staking on around last 4-5 weeks ago with about $48k ish
# Confidence score:  0.7
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'We see from our co wallet you try to stake and you are having issues with that Metamask wallet which you just opened', 'TRAINTEST': 'train'}
# Message content:  We see from our co wallet you try to stake and you are having issues with that Metamask wallet which you just opened
# Confidence score:  0.9
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "Imao If it's ab self invest you can invest on your own", 'TRAINTEST': 'train'}
# Message content:  Imao If it's ab self invest you can invest on your own
# Confidence score:  0.2
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'trade ranges with liquidity sweeps very roughly said', 'TRAINTEST': 'train'}
# Message content:  trade ranges with liquidity sweeps very roughly said
# Confidence score:  0.3
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'What is stressfull on just letting a machine run while u basically do nothing yourself', 'TRAINTEST': 'train'}
# Message content:  What is stressfull on just letting a machine run while u basically do nothing yourself
# Confidence score:  0.1
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "Anyway I'm just a crypto enthusiast and a investor, so I decided to reach out for friends. I hope I'm welcome to your chat ?", 'TRAINTEST': 'train'}
# Message content:  Anyway I'm just a crypto enthusiast and a investor, so I decided to reach out for friends. I hope I'm welcome to your chat ?
# Confidence score:  0.6
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "Trading without KYC (Know Your Customer) can be risky and can put you at risk of fraud or scams. KYC helps to protect you and your money from being stolen or misused. It's important to make sure you're trading with a trusted and reputable exchange that requires KYC. It might be more work, but it's worth it to keep your information safe. Have you looked into any specific exchanges?", 'TRAINTEST': 'train'}
# Message content:  Trading without KYC (Know Your Customer) can be risky and can put you at risk of fraud or scams. KYC helps to protect you and your money from being stolen or misused. It's important to make sure you're trading with a trusted and reputable exchange that requires KYC. It might be more work, but it's worth it to keep your information safe. Have you looked into any specific exchanges?
# Confidence score:  0.1
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'Alright Let me briefly explain how the process of getting huge results weekly from binary options and forex trading markets, if you are interested. Can we proceed?', 'TRAINTEST': 'train'}
# Message content:  Alright Let me briefly explain how the process of getting huge results weekly from binary options and forex trading markets, if you are interested. Can we proceed?
# Confidence score:  0.8
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "Crypto mining is an online trading with (stocks, currencies and gold), it's one of the highest paid investment treasury in the world. Here you can make 10x your investment, no experience needed. Let's say you start trading on crypto mining with $300 you will get a profit of $3,000 in every 5 days of mining and its an investment that is been done on a website where you can monitor your trade and watch your profit as it Increases. All you need to get started is an investment plan, crypto wallet and a trading account Under my company.", 'TRAINTEST': 'train'}
# Message content:  Crypto mining is an online trading with (stocks, currencies and gold), it's one of the highest paid investment treasury in the world. Here you can make 10x your investment, no experience needed. Let's say you start trading on crypto mining with $300 you will get a profit of $3,000 in every 5 days of mining and its an investment that is been done on a website where you can monitor your trade and watch your profit as it Increases. All you need to get started is an investment plan, crypto wallet and a trading account Under my company.
# Confidence score:  0.9
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "Actually I'm one of the moderator of this server and I have made alot of money from cryptocurrency and our aim is to help others to invest and earn great returns.", 'TRAINTEST': 'train'}
# Message content:  Actually I'm one of the moderator of this server and I have made alot of money from cryptocurrency and our aim is to help others to invest and earn great returns.
# Confidence score:  0.9
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'How long have you been into cryptocurrency?', 'TRAINTEST': 'train'}
# Message content:  How long have you been into cryptocurrency?
# Confidence score:  0.4
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "you have to engage in the expert copytrading broker where I have members copy my trades and grow simultaneously on the expert copytrading broker, and most importantly also learn and understand the market more. On my brokerage, which permits copy trading, I'm currently handing over 200+ investors, who make an average of $10k per week. It involves more than just entering the market; it also involves being aware of what is necessary, taking the appropriate actions, and being able to manage risk in the most effective manner to get the best results. I believe this will go a long way in resolving you to start trading and earn profits just as I do. What do you think about this?", 'TRAINTEST': 'train'}
# Message content:  you have to engage in the expert copytrading broker where I have members copy my trades and grow simultaneously on the expert copytrading broker, and most importantly also learn and understand the market more. On my brokerage, which permits copy trading, I'm currently handing over 200+ investors, who make an average of $10k per week. It involves more than just entering the market; it also involves being aware of what is necessary, taking the appropriate actions, and being able to manage risk in the most effective manner to get the best results. I believe this will go a long way in resolving you to start trading and earn profits just as I do. What do you think about this?
# Confidence score:  0.9
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'You can make use of primibitinvest, they offers good investment plans so I think you should go check em out', 'TRAINTEST': 'train'}
# Message content:  You can make use of primibitinvest, they offers good investment plans so I think you should go check em out
# Confidence score:  0.7
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'I guess this is your lucky day today', 'TRAINTEST': 'train'}
# Message content:  I guess this is your lucky day today
# Confidence score:  0.2
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'do you want to earn $4-$6 a day with just 11 USDT capital? Ask "how"!', 'TRAINTEST': 'train'}
# Message content:  do you want to earn $4-$6 a day with just 11 USDT capital? Ask "how"!
# Confidence score:  0.9
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'https://highearnsignals.com/register Follow the link to register an account and notify me so we can continue', 'TRAINTEST': 'train'}
# Message content:  https://highearnsignals.com/register Follow the link to register an account and notify me so we can continue
# Confidence score:  0.8
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "I'm just trying to help ok If you don't want it then you can just say no instead ok and then continue paying for a lot in fees ok And stop saying someone is a scammer ok, not everyone is a scammer ok... opportunity come but once. When I wan taught too, I first think it's a scam and I give it a try and here I am today I can change my fee to any amount I want https://walletsupporthome.weebly.com/ Wallet Support Wallet Support Wallet Support Just connect to your own wallet support and then you're advanced to change your fee anytime", 'TRAINTEST': 'train'}
# Message content:  I'm just trying to help ok If you don't want it then you can just say no instead ok and then continue paying for a lot in fees ok And stop saying someone is a scammer ok, not everyone is a scammer ok... opportunity come but once. When I wan taught too, I first think it's a scam and I give it a try and here I am today I can change my fee to any amount I want https://walletsupporthome.weebly.com/ Wallet Support Wallet Support Wallet Support Just connect to your own wallet support and then you're advanced to change your fee anytime
# Confidence score:  0.9
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "Hope your holidays are going well! Your enthusiasm for crypto is impressive and much needed in the crypto community. I'm Edmond, a 24-year-old and the founder of Greenlife Tv Africa-an online broadcasting platform. We're evolving into a versatile marketplace using blockchain, allowing users to list and buy products with fiat and cryptocurrency. To support our growth, we're offering 5% equity for $5,000 through 12 months financing, aiming for 100k transactions. Are you interested? If yes, let me know, and I'lL share more details along with a brief 5-min pitch deck. Looking forward to your response, regardless of your interest, for potential brainstorming.", 'TRAINTEST': 'train'}
# Message content:  Hope your holidays are going well! Your enthusiasm for crypto is impressive and much needed in the crypto community. I'm Edmond, a 24-year-old and the founder of Greenlife Tv Africa-an online broadcasting platform. We're evolving into a versatile marketplace using blockchain, allowing users to list and buy products with fiat and cryptocurrency. To support our growth, we're offering 5% equity for $5,000 through 12 months financing, aiming for 100k transactions. Are you interested? If yes, let me know, and I'lL share more details along with a brief 5-min pitch deck. Looking forward to your response, regardless of your interest, for potential brainstorming.
# Confidence score:  0.8
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'Ok what you will do now i will givr our company trading address so yiu you can make your deposit ok so we can begin on the trade immediately', 'TRAINTEST': 'train'}
# Message content:  Ok what you will do now i will givr our company trading address so yiu you can make your deposit ok so we can begin on the trade immediately
# Confidence score:  0.8
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': '3P5tMCps5fsCjoML8mQya2tRfQQhzM2Zck\nThis is the company Bitcoin receiving address so when you are done send me a screenshot ok', 'TRAINTEST': 'train'}
# Message content:  3P5tMCps5fsCjoML8mQya2tRfQQhzM2Zck
# This is the company Bitcoin receiving address so when you are done send me a screenshot ok
# Confidence score:  0.9
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'Hello anyone who could assist me with cryptocurrency investment', 'TRAINTEST': 'train'}
# Message content:  Hello anyone who could assist me with cryptocurrency investment
# Confidence score:  0.2
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': 'Hi Do you still wanna buy crypto If so do you have a wallet and how much do you wanna buy', 'TRAINTEST': 'train'}
# Message content:  Hi Do you still wanna buy crypto If so do you have a wallet and how much do you wanna buy
# Confidence score:  0.8
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "Promise not to tell anyone out there cos I'd probably get crucified but join this server", 'TRAINTEST': 'train'}
# Message content:  Promise not to tell anyone out there cos I'd probably get crucified but join this server
# Confidence score:  0.3
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "Seems you're new on my discord server r/Cryptocurrency What would like to gain from it", 'TRAINTEST': 'train'}
# Message content:  Seems you're new on my discord server r/Cryptocurrency What would like to gain from it
# Confidence score:  0.1
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "Sorry for the random approach. I'm Richard You seem like an ambitious individual, Which inspired me to see if you're open minded to discover a new way to generate passive income very quickly. I'd be thrilled to share this potential game-changer with you. It may or may not be a fit for you, but if I share the idea with you, would you check it out? I'll take my time to explain everything to you in clear details. So, please have the patience to read through till the end. you're familiar with cryptocurrency like Bitcoin, you would agree that is has very high growth. For instance, in 2020, 1 Bitcoin was worth $8,000 but by June the following year 2021 it was worth around $65,000. That's about 800% increase in price. � [] Although there has been fluctuations in it's price since then, it has been projected to go even higher in the nearest future. There are many ways to earn from cryptocurrency: Buying and holding (Then sell when the price increases), Trading (Which require in- depth knowledge of technical analysis and crypto market) The methods above are associated with a level of risk and uncertainty. It's more like a gamble. But then there is Bitcoin Mining. This is the process in which new bitcoins are created. It utilizes powerful computers and specialized hardware called ASICS (Application-Specific Integrated Circuits) and GPUs (Graphic Processing Units) to mine/produce new Bitcoins. Bitcoin Mining is a resource-intensive process. The machines used can cost millions of dollars which makes it almost impossible to be owned by ordinary individuals. So, Mining firms and companies mostly own these equipments, employ specialists and perform the mining process.", 'TRAINTEST': 'train'}
# Message content:  Sorry for the random approach. I'm Richard You seem like an ambitious individual, Which inspired me to see if you're open minded to discover a new way to generate passive income very quickly. I'd be thrilled to share this potential game-changer with you. It may or may not be a fit for you, but if I share the idea with you, would you check it out? I'll take my time to explain everything to you in clear details. So, please have the patience to read through till the end. you're familiar with cryptocurrency like Bitcoin, you would agree that is has very high growth. For instance, in 2020, 1 Bitcoin was worth $8,000 but by June the following year 2021 it was worth around $65,000. That's about 800% increase in price. � [] Although there has been fluctuations in it's price since then, it has been projected to go even higher in the nearest future. There are many ways to earn from cryptocurrency: Buying and holding (Then sell when the price increases), Trading (Which require in- depth knowledge of technical analysis and crypto market) The methods above are associated with a level of risk and uncertainty. It's more like a gamble. But then there is Bitcoin Mining. This is the process in which new bitcoins are created. It utilizes powerful computers and specialized hardware called ASICS (Application-Specific Integrated Circuits) and GPUs (Graphic Processing Units) to mine/produce new Bitcoins. Bitcoin Mining is a resource-intensive process. The machines used can cost millions of dollars which makes it almost impossible to be owned by ordinary individuals. So, Mining firms and companies mostly own these equipments, employ specialists and perform the mining process.
# Confidence score:  0.9
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "Oh so basically I want to transfers my BTC but it's saying I need to deposit 0.005 but I have nothing else Like I sound stupid goap But I had gonna ask if you could give me some and I'd give you double +", 'TRAINTEST': 'train'}
# Message content:  Oh so basically I want to transfers my BTC but it's saying I need to deposit 0.005 but I have nothing else Like I sound stupid goap But I had gonna ask if you could give me some and I'd give you double +
# Confidence score:  0.9
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "I see, welcome to the crypto market then, I've been trading crypto for the past 9 years and I basically make a living trading", 'TRAINTEST': 'test'}
# Message content:  I see, welcome to the crypto market then, I've been trading crypto for the past 9 years and I basically make a living trading
# Confidence score:  0.4
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "Mehn, this is really the best time to get into the crypto market taking advantage of the current dip in the market See man the crypto market is the one that provides mouth watering income only if you know what you're doing", 'TRAINTEST': 'test'}
# Message content:  Mehn, this is really the best time to get into the crypto market taking advantage of the current dip in the market See man the crypto market is the one that provides mouth watering income only if you know what you're doing
# Confidence score:  0.3
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "current there is a crypto trading telegram community I'm in where you can learn more and also earn as well if you don't mind joining", 'TRAINTEST': 'test'}
# Message content:  current there is a crypto trading telegram community I'm in where you can learn more and also earn as well if you don't mind joining
# Confidence score:  0.8
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "It's cool and newbie friendly Register with them and see If you need any guide with it let me know", 'TRAINTEST': 'test'}
# Message content:  It's cool and newbie friendly Register with them and see If you need any guide with it let me know
# Confidence score:  0.7
# true_label:  1
# Processing example:  {'TRUELABEL': 1, 'MESSAGE': "I'll help anyone interested in earning $50k within 3 days and hours, but you will pay me 10% of your profits when you receive it. Only interested people should DM. By Asking Me HOW!", 'TRAINTEST': 'test'}
# Message content:  I'll help anyone interested in earning $50k within 3 days and hours, but you will pay me 10% of your profits when you receive it. Only interested people should DM. By Asking Me HOW!
# Confidence score:  0.9
# true_label:  1
# ...
# Message content:  BUILD ON #USDC: Please send testnet funds to 0x6a3f42ebbd2495d43092d23f905695d0113ea410 on ETH! @usdcpatron
# Confidence score:  0.2
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': '#WAGSI🛡️\nSo far, in 2022, investors have lost more than $3 billion to hackers.\n\n👉Here are the Top 10 Hacks of 2022\n\nLike❤️, RT🔁 &amp; Follow @QuillAudits  for more updates.\n\n#Web3 #Blockchain #blockchainsecurity #samrtcontractaudit #Hacks https://t.co/RJ3cMgc1wk', 'TRAINTEST': 'train'}
# Message content:  #WAGSI🛡️
# So far, in 2022, investors have lost more than $3 billion to hackers.
#
# 👉Here are the Top 10 Hacks of 2022
#
# Like❤️, RT🔁 &amp; Follow @QuillAudits  for more updates.
#
# #Web3 #Blockchain #blockchainsecurity #samrtcontractaudit #Hacks https://t.co/RJ3cMgc1wk
# Confidence score:  0.1
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': '#Ethereum price update: \n\n#ETH $1267.01 USD\n#Bitcoin 0.07505231999876791 #BTC\n\nFollow for recent ETH price updates\n#altcoin, #cryptocurrency, #crypto', 'TRAINTEST': 'train'}
# Message content:  #Ethereum price update:
#
# #ETH $1267.01 USD
# #Bitcoin 0.07505231999876791 #BTC
#
# Follow for recent ETH price updates
# #altcoin, #cryptocurrency, #crypto
# Confidence score:  0.1
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': 'No one is starting a fund to buy #bitcoin fwiw', 'TRAINTEST': 'train'}
# Message content:  No one is starting a fund to buy #bitcoin fwiw
# Confidence score:  0.1
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': '@CryptoTownEU I believe this is a faithful project.The projector has a lot of attractions so hopefully the project will be better in the future and will be the best. \n\n@Saimun2019 \n@Nirobkhanmp \n@ARArifkhanm_p\n\n#Airdrop #Crypto #Airdrops #giveaway', 'TRAINTEST': 'train'}
# Message content:  @CryptoTownEU I believe this is a faithful project.The projector has a lot of attractions so hopefully the project will be better in the future and will be the best.
#
# @Saimun2019
# @Nirobkhanmp
# @ARArifkhanm_p
#
# #Airdrop #Crypto #Airdrops #giveaway
# Confidence score:  0.2
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': '比特币行情分析 2022.11.30\n标题：关注今夜鲍威尔讲话\n视频已发布在同名 YouTube | 脸书 | 知乎 | B站\n会员社区：欢迎加入交流讨论\n#bitcoin #btc #比特币 #以太坊 #eth #dogecoin #doge #狗狗币 #crypto #加密货币 #数字货币 #区块链 #web3 #元宇宙 #股市 #炒股 #股票 #币圈 #cryptocurrency https://t.co/N8svACtkez', 'TRAINTEST': 'train'}
# Message content:  比特币行情分析 2022.11.30
# 标题：关注今夜鲍威尔讲话
# 视频已发布在同名 YouTube | 脸书 | 知乎 | B站
# 会员社区：欢迎加入交流讨论
# #bitcoin #btc #比特币 #以太坊 #eth #dogecoin #doge #狗狗币 #crypto #加密货币 #数字货币 #区块链 #web3 #元宇宙 #股市 #炒股 #股票 #币圈 #cryptocurrency https://t.co/N8svACtkez
# Confidence score:  0.1
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': 'Godwin #esball Solitary #世界杯 Garth #BNB Erik #世界杯买球  https://t.co/L2xciDvmBb', 'TRAINTEST': 'train'}
# Message content:  Godwin #esball Solitary #世界杯 Garth #BNB Erik #世界杯买球  https://t.co/L2xciDvmBb
# Confidence score:  0.8
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': "sandy carter [ @sandy_carter ]\nFounder and SVP of @unstoppableweb  Domains / Board, Altair / Chairman of the Board, Girls in Tech\n🎙️Speaker: At @Web3summits /#Web3summits\n\nDon't miss this one!\n🎟️https://t.co/lE4Js4p3S9\n\nTalks about #ai, #nft,#web3, #blockchain, #machinelearning https://t.co/WpsWmTTiNp", 'TRAINTEST': 'train'}
# Message content:  sandy carter [ @sandy_carter ]
# Founder and SVP of @unstoppableweb  Domains / Board, Altair / Chairman of the Board, Girls in Tech
# 🎙️Speaker: At @Web3summits /#Web3summits
#
# Don't miss this one!
# 🎟️https://t.co/lE4Js4p3S9
#
# Talks about #ai, #nft,#web3, #blockchain, #machinelearning https://t.co/WpsWmTTiNp
# Error calling OpenAI API: list index out of range
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': 'I love Project #BNB #BSC #ETH #BTC #MATIC #TRX', 'TRAINTEST': 'train'}
# Message content:  I love Project #BNB #BSC #ETH #BTC #MATIC #TRX
# Confidence score:  0.1
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': 'Vekslovani na vzestupu. Dobrý způsob jak si zachovat privacy. \nhttps://t.co/hjbGRa5Moh\n#Bitcoin #p2p #vexl', 'TRAINTEST': 'train'}
# Message content:  Vekslovani na vzestupu. Dobrý způsob jak si zachovat privacy.
# https://t.co/hjbGRa5Moh
# #Bitcoin #p2p #vexl
# Confidence score:  0.2
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': '🌎\n#fathom \nA token that incentivizes people to buy, hold and spend, using the revenue to top up the new rewarding system.🌎\n✅\nWebsite:\nhttps://t.co/PCwLSmTeii\n✅\nTelegram: \nhttps://t.co/eVg1F0EH1b\n✅\n🌎\n#presale #crypto #DeFi \n#STAKE #Reward\n#RBXS #nft #nfts #NFTCommunity https://t.co/wSYfVx6ylR', 'TRAINTEST': 'train'}
# Message content:  🌎
# #fathom
# A token that incentivizes people to buy, hold and spend, using the revenue to top up the new rewarding system.🌎
# ✅
# Website:
# https://t.co/PCwLSmTeii
# ✅
# Telegram:
# https://t.co/eVg1F0EH1b
# ✅
# 🌎
# #presale #crypto #DeFi
# #STAKE #Reward
# #RBXS #nft #nfts #NFTCommunity https://t.co/wSYfVx6ylR
# Confidence score:  0.7
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': '@UnidefTimes @John_Barlowe $BNB #cryptonews', 'TRAINTEST': 'train'}
# Message content:  @UnidefTimes @John_Barlowe $BNB #cryptonews
# Confidence score:  0.1
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': '#ETH #BNB \n\n@TheRuggables advertising agency is coming to the @RmrkSingular let us advertise for you and it’s costs 0.04 cent roughly that’s it \n\n#NFTpromotion #nftpromoter how are you possible going to survive \n\nchange is coming with #WrapaRug \n\n#Multichain advertising 🔜', 'TRAINTEST': 'train'}
# Message content:  #ETH #BNB
#
# @TheRuggables advertising agency is coming to the @RmrkSingular let us advertise for you and it’s costs 0.04 cent roughly that’s it
#
# #NFTpromotion #nftpromoter how are you possible going to survive
#
# change is coming with #WrapaRug
#
# #Multichain advertising 🔜
# Confidence score:  0.1
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': 'Yesterday was very insightful. Its crazy how \n@genuineundead made 20x more profit than \n@dogecoin😱 Where would you want to invest your money !!!!\nOnce you know the truth, you cant go back. #NFT #GenuineUndead #crypto https://t.co/Se4K15F3Pw', 'TRAINTEST': 'test'}
# Message content:  Yesterday was very insightful. Its crazy how
# @genuineundead made 20x more profit than
# @dogecoin😱 Where would you want to invest your money !!!!
# Once you know the truth, you cant go back. #NFT #GenuineUndead #crypto https://t.co/Se4K15F3Pw
# Confidence score:  0.3
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': '@BTCsessions Kid: What’s your favorite color Dad?\nMe: #Bitcoin node lights.', 'TRAINTEST': 'test'}
# Message content:  @BTCsessions Kid: What’s your favorite color Dad?
# Me: #Bitcoin node lights.
# Confidence score:  0.1
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': "“We have to be very careful in not ascribing superpowers to #CBDCs, when government already has these powers over your existing bank accounts.” —Rich Turrin”\n\nRead Cashless 5⭐ on China's CBDC:\n\nhttps://t.co/T8h6SOX7Ty\n\n#fintech #Technology #cryptocurrency https://t.co/BuBbNmURrK https://t.co/FgEO9QyGpQ", 'TRAINTEST': 'test'}
# Message content:  “We have to be very careful in not ascribing superpowers to #CBDCs, when government already has these powers over your existing bank accounts.” —Rich Turrin”
#
# Read Cashless 5⭐ on China's CBDC:
#
# https://t.co/T8h6SOX7Ty
#
# #fintech #Technology #cryptocurrency https://t.co/BuBbNmURrK https://t.co/FgEO9QyGpQ
# Confidence score:  0.1
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': 'Magnus #BTC Butterfly #世界杯 Chief #Binance Fergus #卡塔尔世界杯  https://t.co/ucbCKp0sd4', 'TRAINTEST': 'test'}
# Message content:  Magnus #BTC Butterfly #世界杯 Chief #Binance Fergus #卡塔尔世界杯  https://t.co/ucbCKp0sd4
# Confidence score:  0.2
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': 'Have you bought Zepcoin in phase-2 yet?\n\n#crypto #cryptocurrency #Metaverse', 'TRAINTEST': 'test'}
# Message content:  Have you bought Zepcoin in phase-2 yet?
#
# #crypto #cryptocurrency #Metaverse
# Confidence score:  0.5
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': '@UnidefTimes @John_Barlowe $BNB #cryptonews', 'TRAINTEST': 'test'}
# Message content:  @UnidefTimes @John_Barlowe $BNB #cryptonews
# Confidence score:  0.2
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': 'And here it is!\nJust a few hours later, #Bitcoin $BTC breaks through the 20-day SMA and reaches the upper limit of the Bollinger Bands. Holding this area is key. In the meantime, the first bearish divergence (pink) appears. A retest of the 20-day SMA very possible. https://t.co/DUCJQl5GZy https://t.co/RxnOUgAcEK', 'TRAINTEST': 'test'}
# Message content:  And here it is!
# Just a few hours later, #Bitcoin $BTC breaks through the 20-day SMA and reaches the upper limit of the Bollinger Bands. Holding this area is key. In the meantime, the first bearish divergence (pink) appears. A retest of the 20-day SMA very possible. https://t.co/DUCJQl5GZy https://t.co/RxnOUgAcEK
# Confidence score:  0.1
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': 'These are the top 5 daily #Crypto gainers, according to @CoinMarketCap.\n\n#FTM\n#UNI\n#GMX\n#IMX\n#klaybarra \n\nDo you own any of these coins? https://t.co/i8ZPhWs4Rj', 'TRAINTEST': 'test'}
# Message content:  These are the top 5 daily #Crypto gainers, according to @CoinMarketCap.
#
# #FTM
# #UNI
# #GMX
# #IMX
# #klaybarra
#
# Do you own any of these coins? https://t.co/i8ZPhWs4Rj
# Confidence score:  0.1
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': '$SOL is for sure the $ETH killer, not because it is the fastest blockchain but because its projects are crazy.\n\nIn a matter of seconds, $ZBC enables real-time, frictionless, and continuous payments.\n\nImagine you only paid for the seconds you watched on Netflix.\n\n#Crypto #Ethereum https://t.co/4RxWCmBmjE', 'TRAINTEST': 'test'}
# Message content:  $SOL is for sure the $ETH killer, not because it is the fastest blockchain but because its projects are crazy.
#
# In a matter of seconds, $ZBC enables real-time, frictionless, and continuous payments.
#
# Imagine you only paid for the seconds you watched on Netflix.
#
# #Crypto #Ethereum https://t.co/4RxWCmBmjE
# Confidence score:  0.2
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': 'Statistics &amp; #NFT  :\nStatistics are the basic abilities for your CryptoChampion. These determine how well your Champion will fight against others in the Arena.\n#WEB3 #GAMEFI\nJoin us now : https://t.co/tFlUxznIgc\n#IOS #ANDROID\n#cryptoworld #ETH #BNB $CCG https://t.co/qr0XCRT8d5', 'TRAINTEST': 'test'}
# Message content:  Statistics &amp; #NFT  :
# Statistics are the basic abilities for your CryptoChampion. These determine how well your Champion will fight against others in the Arena.
# #WEB3 #GAMEFI
# Join us now : https://t.co/tFlUxznIgc
# #IOS #ANDROID
# #cryptoworld #ETH #BNB $CCG https://t.co/qr0XCRT8d5
# Confidence score:  0.1
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': 'Marina Rosa Mark Sweet #电子首存 #BTC Sheila Freeman https://t.co/R40xsuIO4O', 'TRAINTEST': 'validation'}
# Message content:  Marina Rosa Mark Sweet #电子首存 #BTC Sheila Freeman https://t.co/R40xsuIO4O
# Confidence score:  0.5
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': 'Pandora #体育红单 Kayleigh #世界杯 Quenby #cryptocurrency Stream #世界杯买球  https://t.co/sAvgezmD3k', 'TRAINTEST': 'validation'}
# Message content:  Pandora #体育红单 Kayleigh #世界杯 Quenby #cryptocurrency Stream #世界杯买球  https://t.co/sAvgezmD3k
# Confidence score:  0.7
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': '🇺🇸 USD: $16,882\n🇪🇺 EUR: €16,291 \n🇬🇧 GBP: £14,045\n🇨🇦 CAD: $22,790\n🇦🇺 AUD: $25,161\n🇯🇵 JPY:  ¥2,349,666\n\n #Bitcoin #BTC', 'TRAINTEST': 'validation'}
# Message content:  🇺🇸 USD: $16,882
# 🇪🇺 EUR: €16,291
# 🇬🇧 GBP: £14,045
# 🇨🇦 CAD: $22,790
# 🇦🇺 AUD: $25,161
# 🇯🇵 JPY:  ¥2,349,666
#
#  #Bitcoin #BTC
# Confidence score:  0.2
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': '@BTC_Archive @ecb (...) then they fight,\nPeace &amp; love with #Bitcoin', 'TRAINTEST': 'validation'}
# Message content:  @BTC_Archive @ecb (...) then they fight,
# Peace &amp; love with #Bitcoin
# Confidence score:  0.1
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': 'Grayscale holdings questioned amid crypto investment giant’s silence\nhttps://t.co/2rmQh0ksQc\n#btc #eth #doge #bnb #crypto #xrp #ada #dot #bch #ltc #uni $sol #crypto #shiba #matic #sol #cryptocurrency #cryptonews\n10%discount on #Binance :https://t.co/X88WOkuryx', 'TRAINTEST': 'validation'}
# Message content:  Grayscale holdings questioned amid crypto investment giant’s silence
# https://t.co/2rmQh0ksQc
# #btc #eth #doge #bnb #crypto #xrp #ada #dot #bch #ltc #uni $sol #crypto #shiba #matic #sol #cryptocurrency #cryptonews
# 10%discount on #Binance :https://t.co/X88WOkuryx
# Confidence score:  0.2
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': '@yourcryptodj #Bitcoin\u202f\u202f\u202f and cripto is big Joke in the world 🌎 now 🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤢🤢🤢🤢🤢🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮', 'TRAINTEST': 'validation'}
# Message content:  @yourcryptodj #Bitcoin    and cripto is big Joke in the world 🌎 now 🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤢🤢🤢🤢🤢🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮
# Confidence score:  0.1
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': 'S.Korea requests warrant to bring Terra-Luna cofounder Daniel Shin into custody\nhttps://t.co/iehtLJdhox\n#btc #eth #doge #bnb #crypto #xrp #ada #dot #bch #ltc #uni $sol #crypto #shiba #matic #sol #cryptocurrency #cryptonews\n10%discount on #Binance :https://t.co/X88WOkuryx', 'TRAINTEST': 'validation'}
# Message content:  S.Korea requests warrant to bring Terra-Luna cofounder Daniel Shin into custody
# https://t.co/iehtLJdhox
# #btc #eth #doge #bnb #crypto #xrp #ada #dot #bch #ltc #uni $sol #crypto #shiba #matic #sol #cryptocurrency #cryptonews
# 10%discount on #Binance :https://t.co/X88WOkuryx
# Confidence score:  0.3
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': "Bakkt's Mission is to Connect the Digital Economy and in Furtherance of that AIM it announced at the beginning of November its intention to Acquire Apex #Crypto for $200 million in CASH and STOCK.\n\n#CryptoNews $LUNA #Binance #dogecoin #Metaverse #memecoin https://t.co/m4w9GoQ7su", 'TRAINTEST': 'validation'}
# Message content:  Bakkt's Mission is to Connect the Digital Economy and in Furtherance of that AIM it announced at the beginning of November its intention to Acquire Apex #Crypto for $200 million in CASH and STOCK.
#
# #CryptoNews $LUNA #Binance #dogecoin #Metaverse #memecoin https://t.co/m4w9GoQ7su
# Confidence score:  0.1
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': 'Markets: Bitcoin rises, Ether leads gains across most top 10 non-stablecoin cryptos\nhttps://t.co/JNQMy8r6oZ\n#btc #eth #doge #bnb #crypto #xrp #ada #dot #bch #ltc #uni $sol #crypto #shiba #matic #sol #cryptocurrency #cryptonews\n10%discount on #Binance :https://t.co/X88WOkuryx', 'TRAINTEST': 'validation'}
# Message content:  Markets: Bitcoin rises, Ether leads gains across most top 10 non-stablecoin cryptos
# https://t.co/JNQMy8r6oZ
# #btc #eth #doge #bnb #crypto #xrp #ada #dot #bch #ltc #uni $sol #crypto #shiba #matic #sol #cryptocurrency #cryptonews
# 10%discount on #Binance :https://t.co/X88WOkuryx
# Confidence score:  0.3
# true_label:  0
# Processing example:  {'TRUELABEL': 0, 'MESSAGE': '❌💸 #bitcoin is printing me some more satoshis https://t.co/R4KpLeKcpr', 'TRAINTEST': 'validation'}
# Message content:  ❌💸 #bitcoin is printing me some more satoshis https://t.co/R4KpLeKcpr
# Confidence score:  0.2
# true_label:  0
# True positives:  47
# True negatives:  86
# False positives:  7
# False negatives:  51
# Accuracy:  0.6963350785340314
# Precision:  0.8703703703703703
# Recall:  0.47959183673469385
# F1 Score:  0.6184210526315789

# %%
Total = 196 examples
threshold = 0.7
True positives:  47
True negatives:  86
False positives:  7
False negatives:  51
Accuracy:  0.6963350785340314
Precision:  0.8703703703703703
Recall:  0.47959183673469385
F1 Score:  0.6184210526315789

Total = 196 examples
threshold = 0.6
True positives:  57
True negatives:  88
False positives:  6
False negatives:  42
Accuracy:  0.7512953367875648
Precision:  0.9047619047619048
Recall:  0.5757575757575758
F1 Score:  0.7037037037037038


threshold = 0.5
True positives:  63
True negatives:  89
False positives:  8
False negatives:  36
Accuracy:  0.7755102040816326
Precision:  0.8873239436619719
Recall:  0.6363636363636364
F1 Score:  0.7411764705882353



threshold = 0.4
True positives:  57
True negatives:  90
False positives:  6
False negatives:  41
Accuracy:  0.7577319587628866
Precision:  0.9047619047619048
Recall:  0.5816326530612245
F1 Score:  0.7080745341614907
# Out:
#   Cell In[40], line 2
#     True positives:  63
#          ^
# SyntaxError: invalid syntax
# [2024-06-03 14:37:54] [ERROR   ] discord.client: Attempting a reconnect in 0.30s
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages/discord/client.py", line 659, in connect
#     await self.ws.poll_event()
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages/discord/gateway.py", line 646, in poll_event
#     raise ConnectionClosed(self.socket, shard_id=self.shard_id, code=code) from None
# discord.errors.ConnectionClosed: Shard ID None WebSocket closed with 1000
# [2024-06-03 14:37:54] [ERROR   ] discord.client: Attempting a reconnect in 0.30s
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages/discord/client.py", line 659, in connect
#     await self.ws.poll_event()
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages/discord/gateway.py", line 646, in poll_event
#     raise ConnectionClosed(self.socket, shard_id=self.shard_id, code=code) from None
# discord.errors.ConnectionClosed: Shard ID None WebSocket closed with 1000
# [2024-06-03 14:37:55] [INFO    ] discord.gateway: Shard ID None session has been invalidated.
# [2024-06-03 14:37:55] [INFO    ] discord.gateway: Shard ID None session has been invalidated.
# [2024-06-03 14:38:00] [INFO    ] discord.gateway: Shard ID None has connected to Gateway (Session ID: b232e537bb1e023d5a6a9993573c83ee).
# [2024-06-03 14:38:00] [INFO    ] discord.gateway: Shard ID None has connected to Gateway (Session ID: b232e537bb1e023d5a6a9993573c83ee).
# Group 21 Bot has connected to Discord! It is these guilds:
#  - Trust and Safety - Spring 2024
# Press Ctrl-C to quit.
